# %% [markdown]
# FACIAL RECOGNITION PROJECT
#     What to do
# 1. Create a Function that takes in folders of pictures sets a limit to the number of pictures to at least have
# 2. Create a function that detect faces with haar cascades from opencv and outputs a cropped version cut by the bounding box
# 3. Create a function that takes in the pictures with the names and does th face regonition( Facenet)
# 4. Do the face recognition
# 5. MAybe make a webapp with the model as the api
# 6. Run it on a video feed
# 7. Avoid repitition of names
# 8. Add the time stamps of the entry

# %%
#importing important libraries 
import cv2 
#import Keras
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
from imutils.face_utils import FaceAligner
#import face_recognition

# %%
#bringing in images from folders
images = list(paths.list_images('./images'))
images
# Out:
# ['./images\\favour\\IMG_0611.jpg',
#  './images\\favour\\IMG_0612.jpg',
#  './images\\favour\\IMG_0613.jpg',
#  './images\\favour\\IMG_0773.jpg',
#  './images\\favour\\IMG_0775.jpg',
#  './images\\favour\\IMG_0776.jpg']

# %%
#reading into cv2

image_1 = cv2.imread(images[3])
#copy image
image_copy = np.copy(image_1)
#original image
image_1 = cv2.cvtColor(image_1, cv2.COLOR_BGR2RGB)
#copy rgb to gray
image_1_gray = cv2.cvtColor(image_copy, cv2.COLOR_BGR2GRAY)

plt.imshow(image_1, cmap ='gray')

# %%
#face detection
def detect_faces( image_orig):
    face_detect_weight = 'haarcascade_frontalface_default.xml'
    #resizing the image to make it the same throughout
    #new_size_image_copy = cv2.resize(image_copy, (300,300))
    #new_size_image_orig = cv2.resize(image_orig, (300,300))
    #using the haarcascade weight
    net = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    #print(net.empty())
    #fa = FaceAligner(net, desiredFaceWidth=256)
    #detecting the face
    
    
    face = net.detectMultiScale(image_orig, 1.6, 5)
    print(face)
    for (x,y,w,h) in face:
        print(x), print(y),print(w),print(h)
    #drawing the bounding boxes over the original copy of the image
        cv2.rectangle(image_orig, (x, y), (x+w,y+h),(255,0,0),3)
    
    #cropped_image = new_size_image_orig[y:y+h ,x:x+w]
    #faceAligned = fa.align(new_size_image_orig, new_size_image_copy, rect)
    
    #resize to 160x160 to prepare it for faceNet
    #cropped_image = cv2.resize(cropped_image, (160,160), cv2.INTER_CUBIC)
    
    
    
    #display images
    
    #f,(ax1,ax2) = plt.subplots(1,2,figsize=(20,10))
    #ax1.set_title('Full size image')
    #ax1.imshow(new_size_image_orig)
    
    #ax2.set_title('Cropped Image')
    #ax2.imshow(cropped_image)
    
    #ax3.set_title('Aligned Image')
    #ax3.imshow(faceAligned)
    
    #return new_size_image_orig

# %%
img = detect_faces( image_1)
# Out:
# [[ 584  429 1649 1649]]
# 584
# 429
# 1649
# 1649

# %%
#Video Stream 

video_reading = cv2.VideoCapture(0)

while True:
    ret, val = video_reading.read()
    detect_faces(val)
    cv2.imshow("Frame", val)
    key = cv2.waitKey(1) & 0xFF
    if key == ord("q"):
        break
video_capture.release()
cv2.destroyAllWindows()
# Out:
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ...

# %%
#help cell
help(cv2.CascadeClassifier)
# Out:
# Help on class CascadeClassifier in module cv2:
#
# class CascadeClassifier(builtins.object)
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  detectMultiScale(...)
#  |      detectMultiScale(image[, scaleFactor[, minNeighbors[, flags[, minSize[, maxSize]]]]]) -> objects
#  |      .   @brief Detects objects of different sizes in the input image. The detected objects are returned as a list
#  |      .   of rectangles.
#  |      .
#  |      .   @param image Matrix of the type CV_8U containing an image where objects are detected.
#  |      .   @param objects Vector of rectangles where each rectangle contains the detected object, the
#  |      .   rectangles may be partially outside the original image.
#  |      .   @param scaleFactor Parameter specifying how much the image size is reduced at each image scale.
# ...

# %%
import deepface
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-14eb5be4d61e> in <module>
# ----> 1 import deepface
#
# ModuleNotFoundError: No module named 'deepface'
